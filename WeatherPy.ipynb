# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 618

# %%
# Import the requests library.
import requests

# Import the API Key.
from config import weather_api_key

#starting url for weather map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grindavik
# Processing Record 2 of Set 1 | victoria
# Processing Record 3 of Set 1 | catamarca
# Processing Record 4 of Set 1 | leningradskiy
# Processing Record 5 of Set 1 | ust-nera
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 14 of Set 1 | ahtopol
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | watrous
# Processing Record 17 of Set 1 | merauke
# Processing Record 18 of Set 1 | teya
# Processing Record 19 of Set 1 | lac-megantic
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | kimbe
# Processing Record 23 of Set 1 | flinders
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | vila velha
# Processing Record 26 of Set 1 | airai
# Processing Record 27 of Set 1 | nisia floresta
# Processing Record 28 of Set 1 | bathsheba
# Processing Record 29 of Set 1 | clyde river
# Processing Record 30 of Set 1 | kavieng
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | port hardy
# Processing Record 34 of Set 1 | sisimiut
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | erzin
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | vardo
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | port hedland
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | bonga
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | mayo
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | kollumerland
# City not found. Skipping...
# Processing Record 48 of Set 1 | kitimat
# Processing Record 49 of Set 1 | ocala
# Processing Record 50 of Set 1 | trairi
# Processing Record 1 of Set 2 | ngunguru
# Processing Record 2 of Set 2 | ishigaki
# Processing Record 3 of Set 2 | pacific grove
# Processing Record 4 of Set 2 | along
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | okitipupa
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | pemangkat
# Processing Record 9 of Set 2 | racine
# Processing Record 10 of Set 2 | grand gaube
# Processing Record 11 of Set 2 | byron bay
# Processing Record 12 of Set 2 | faanui
# Processing Record 13 of Set 2 | plettenberg bay
# Processing Record 14 of Set 2 | omsukchan
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | fuerte olimpo
# Processing Record 19 of Set 2 | leshukonskoye
# Processing Record 20 of Set 2 | haverfordwest
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | ostrovnoy
# Processing Record 23 of Set 2 | fernley
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | esperance
# Processing Record 26 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | oelde
# Processing Record 29 of Set 2 | guaruja
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | tsentralnyy
# City not found. Skipping...
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | rio gallegos
# Processing Record 35 of Set 2 | southbridge
# Processing Record 36 of Set 2 | saint anthony
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | catuday
# Processing Record 39 of Set 2 | mahon
# Processing Record 40 of Set 2 | mach
# Processing Record 41 of Set 2 | ust-omchug
# Processing Record 42 of Set 2 | paragominas
# Processing Record 43 of Set 2 | ponta do sol
# Processing Record 44 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 45 of Set 2 | yumen
# Processing Record 46 of Set 2 | avera
# Processing Record 47 of Set 2 | cap malheureux
# Processing Record 48 of Set 2 | aklavik
# Processing Record 49 of Set 2 | hilo
# Processing Record 50 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 3 | mount gambier
# Processing Record 3 of Set 3 | stornoway
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | fort-shevchenko
# Processing Record 6 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | akhalgori
# Processing Record 9 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | sola
# Processing Record 12 of Set 3 | yanam
# Processing Record 13 of Set 3 | kapaa
# Processing Record 14 of Set 3 | macenta
# Processing Record 15 of Set 3 | umm lajj
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 3 | husavik
# Processing Record 20 of Set 3 | padang
# Processing Record 21 of Set 3 | cayenne
# Processing Record 22 of Set 3 | prince rupert
# Processing Record 23 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 3 | cape town
# Processing Record 25 of Set 3 | russell
# Processing Record 26 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 3 | yulara
# Processing Record 28 of Set 3 | nanaimo
# Processing Record 29 of Set 3 | marawi
# Processing Record 30 of Set 3 | manono
# Processing Record 31 of Set 3 | kruisfontein
# Processing Record 32 of Set 3 | novouzensk
# Processing Record 33 of Set 3 | mafeteng
# Processing Record 34 of Set 3 | impfondo
# Processing Record 35 of Set 3 | alofi
# Processing Record 36 of Set 3 | maniitsoq
# Processing Record 37 of Set 3 | necochea
# Processing Record 38 of Set 3 | geraldton
# Processing Record 39 of Set 3 | saldanha
# Processing Record 40 of Set 3 | vostok
# Processing Record 41 of Set 3 | jamestown
# Processing Record 42 of Set 3 | ribeira grande
# Processing Record 43 of Set 3 | craig
# Processing Record 44 of Set 3 | naruto
# Processing Record 45 of Set 3 | bambous virieux
# Processing Record 46 of Set 3 | kamenka
# Processing Record 47 of Set 3 | ihosy
# Processing Record 48 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 3 | bilibino
# Processing Record 50 of Set 3 | sayansk
# Processing Record 1 of Set 4 | tasiilaq
# Processing Record 2 of Set 4 | namatanai
# Processing Record 3 of Set 4 | lebu
# Processing Record 4 of Set 4 | mehnagar
# Processing Record 5 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 4 | sompeta
# Processing Record 7 of Set 4 | birao
# Processing Record 8 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 4 | hit
# Processing Record 10 of Set 4 | portland
# Processing Record 11 of Set 4 | nikolskoye
# Processing Record 12 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 4 | inirida
# Processing Record 14 of Set 4 | chokurdakh
# Processing Record 15 of Set 4 | vao
# Processing Record 16 of Set 4 | nyurba
# Processing Record 17 of Set 4 | galveston
# Processing Record 18 of Set 4 | kholtoson
# Processing Record 19 of Set 4 | panama city
# Processing Record 20 of Set 4 | christchurch
# Processing Record 21 of Set 4 | dongsheng
# Processing Record 22 of Set 4 | severo-kurilsk
# Processing Record 23 of Set 4 | saint george
# Processing Record 24 of Set 4 | tingi
# Processing Record 25 of Set 4 | jimeta
# Processing Record 26 of Set 4 | lokoja
# Processing Record 27 of Set 4 | manzil tamim
# City not found. Skipping...
# Processing Record 28 of Set 4 | provideniya
# Processing Record 29 of Set 4 | walvis bay
# Processing Record 30 of Set 4 | marsa matruh
# Processing Record 31 of Set 4 | opuwo
# Processing Record 32 of Set 4 | agua dulce
# Processing Record 33 of Set 4 | karratha
# Processing Record 34 of Set 4 | rio das pedras
# Processing Record 35 of Set 4 | upernavik
# Processing Record 36 of Set 4 | kisangani
# Processing Record 37 of Set 4 | bandarbeyla
# Processing Record 38 of Set 4 | lata
# Processing Record 39 of Set 4 | san quintin
# Processing Record 40 of Set 4 | wanderlandia
# City not found. Skipping...
# Processing Record 41 of Set 4 | hurghada
# Processing Record 42 of Set 4 | calog
# City not found. Skipping...
# Processing Record 43 of Set 4 | rawson
# Processing Record 44 of Set 4 | ilulissat
# Processing Record 45 of Set 4 | fort william
# Processing Record 46 of Set 4 | inveraray
# City not found. Skipping...
# Processing Record 47 of Set 4 | maun
# Processing Record 48 of Set 4 | codrington
# Processing Record 49 of Set 4 | iringa
# Processing Record 50 of Set 4 | perivolion
# Processing Record 1 of Set 5 | port lincoln
# Processing Record 2 of Set 5 | khatanga
# Processing Record 3 of Set 5 | raudeberg
# Processing Record 4 of Set 5 | arraial do cabo
# Processing Record 5 of Set 5 | coahuayana
# Processing Record 6 of Set 5 | moose factory
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | dingle
# Processing Record 9 of Set 5 | sept-iles
# Processing Record 10 of Set 5 | axim
# Processing Record 11 of Set 5 | aviles
# Processing Record 12 of Set 5 | constitucion
# Processing Record 13 of Set 5 | ugoofaaru
# Processing Record 14 of Set 5 | las vegas
# Processing Record 15 of Set 5 | ambovombe
# Processing Record 16 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 18 of Set 5 | korla
# Processing Record 19 of Set 5 | sharjah
# Processing Record 20 of Set 5 | puerto colombia
# Processing Record 21 of Set 5 | ancud
# Processing Record 22 of Set 5 | mar del plata
# Processing Record 23 of Set 5 | hami
# Processing Record 24 of Set 5 | palmer
# Processing Record 25 of Set 5 | evensk
# Processing Record 26 of Set 5 | dubrovnik
# Processing Record 27 of Set 5 | leh
# Processing Record 28 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 30 of Set 5 | tromso
# Processing Record 31 of Set 5 | meulaboh
# Processing Record 32 of Set 5 | nome
# Processing Record 33 of Set 5 | klaksvik
# Processing Record 34 of Set 5 | sao joao da barra
# Processing Record 35 of Set 5 | mulchen
# Processing Record 36 of Set 5 | luderitz
# Processing Record 37 of Set 5 | crossville
# Processing Record 38 of Set 5 | zhob
# Processing Record 39 of Set 5 | matata
# Processing Record 40 of Set 5 | ahipara
# Processing Record 41 of Set 5 | todos santos
# Processing Record 42 of Set 5 | samana
# Processing Record 43 of Set 5 | westport
# Processing Record 44 of Set 5 | pochutla
# Processing Record 45 of Set 5 | talnakh
# Processing Record 46 of Set 5 | pringsewu
# Processing Record 47 of Set 5 | ojinaga
# Processing Record 48 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 5 | golden
# Processing Record 50 of Set 5 | hobyo
# Processing Record 1 of Set 6 | wanning
# Processing Record 2 of Set 6 | cherskiy
# Processing Record 3 of Set 6 | atuona
# Processing Record 4 of Set 6 | richards bay
# Processing Record 5 of Set 6 | rajanpur
# Processing Record 6 of Set 6 | mpika
# Processing Record 7 of Set 6 | saskylakh
# Processing Record 8 of Set 6 | vila franca do campo
# Processing Record 9 of Set 6 | north platte
# Processing Record 10 of Set 6 | bundaberg
# Processing Record 11 of Set 6 | kodiak
# Processing Record 12 of Set 6 | puerto baquerizo moreno
# Processing Record 13 of Set 6 | cidreira
# Processing Record 14 of Set 6 | flin flon
# Processing Record 15 of Set 6 | holme
# Processing Record 16 of Set 6 | sibenik
# Processing Record 17 of Set 6 | jalingo
# Processing Record 18 of Set 6 | waddan
# Processing Record 19 of Set 6 | san patricio
# Processing Record 20 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 21 of Set 6 | castro
# Processing Record 22 of Set 6 | chifeng
# Processing Record 23 of Set 6 | haapiti
# Processing Record 24 of Set 6 | gat
# Processing Record 25 of Set 6 | sao filipe
# Processing Record 26 of Set 6 | longyearbyen
# Processing Record 27 of Set 6 | bengkulu
# Processing Record 28 of Set 6 | larsnes
# Processing Record 29 of Set 6 | lahij
# Processing Record 30 of Set 6 | bobcaygeon
# Processing Record 31 of Set 6 | fairbanks
# Processing Record 32 of Set 6 | malanje
# Processing Record 33 of Set 6 | kapoeta
# Processing Record 34 of Set 6 | muros
# Processing Record 35 of Set 6 | marathon
# Processing Record 36 of Set 6 | hervey bay
# Processing Record 37 of Set 6 | abong mbang
# Processing Record 38 of Set 6 | new baltimore
# Processing Record 39 of Set 6 | carnarvon
# Processing Record 40 of Set 6 | puro
# Processing Record 41 of Set 6 | lompoc
# Processing Record 42 of Set 6 | aleysk
# Processing Record 43 of Set 6 | arrecife
# Processing Record 44 of Set 6 | sakakah
# Processing Record 45 of Set 6 | mahebourg
# Processing Record 46 of Set 6 | ceres
# Processing Record 47 of Set 6 | rundu
# Processing Record 48 of Set 6 | cap-aux-meules
# Processing Record 49 of Set 6 | katete
# Processing Record 50 of Set 6 | aloleng
# Processing Record 1 of Set 7 | chushan
# Processing Record 2 of Set 7 | narsaq
# Processing Record 3 of Set 7 | west wendover
# Processing Record 4 of Set 7 | broome
# Processing Record 5 of Set 7 | port keats
# Processing Record 6 of Set 7 | tura
# Processing Record 7 of Set 7 | butembo
# Processing Record 8 of Set 7 | pangnirtung
# Processing Record 9 of Set 7 | sulina
# Processing Record 10 of Set 7 | samfya
# Processing Record 11 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 7 | dryden
# Processing Record 13 of Set 7 | svetlogorsk
# Processing Record 14 of Set 7 | iqaluit
# Processing Record 15 of Set 7 | honiara
# Processing Record 16 of Set 7 | hofn
# Processing Record 17 of Set 7 | siyabuswa
# Processing Record 18 of Set 7 | antigonish
# Processing Record 19 of Set 7 | pedernales
# Processing Record 20 of Set 7 | namibe
# Processing Record 21 of Set 7 | miracema do tocantins
# Processing Record 22 of Set 7 | port blair
# Processing Record 23 of Set 7 | bay roberts
# Processing Record 24 of Set 7 | acapulco
# Processing Record 25 of Set 7 | matara
# Processing Record 26 of Set 7 | dunedin
# Processing Record 27 of Set 7 | el sauzal
# Processing Record 28 of Set 7 | tynda
# Processing Record 29 of Set 7 | lagoa
# Processing Record 30 of Set 7 | port macquarie
# Processing Record 31 of Set 7 | yaan
# Processing Record 32 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 33 of Set 7 | marondera
# Processing Record 34 of Set 7 | avanigadda
# Processing Record 35 of Set 7 | davila
# Processing Record 36 of Set 7 | pisco
# Processing Record 37 of Set 7 | asau
# Processing Record 38 of Set 7 | samarai
# Processing Record 39 of Set 7 | aztec
# Processing Record 40 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 7 | yerbogachen
# Processing Record 42 of Set 7 | chuy
# Processing Record 43 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 7 | sorland
# Processing Record 45 of Set 7 | severodvinsk
# Processing Record 46 of Set 7 | loharu
# Processing Record 47 of Set 7 | antofagasta
# Processing Record 48 of Set 7 | bondo
# Processing Record 49 of Set 7 | buala
# Processing Record 50 of Set 7 | pekalongan
# Processing Record 1 of Set 8 | manokwari
# Processing Record 2 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 3 of Set 8 | mogadishu
# Processing Record 4 of Set 8 | puerto berrio
# Processing Record 5 of Set 8 | bin qirdan
# Processing Record 6 of Set 8 | gamboma
# Processing Record 7 of Set 8 | niquero
# Processing Record 8 of Set 8 | kota bahru
# Processing Record 9 of Set 8 | banda aceh
# Processing Record 10 of Set 8 | touros
# Processing Record 11 of Set 8 | natal
# Processing Record 12 of Set 8 | port augusta
# Processing Record 13 of Set 8 | mayumba
# Processing Record 14 of Set 8 | shahrud
# Processing Record 15 of Set 8 | prykolotne
# Processing Record 16 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 8 | el alto
# Processing Record 19 of Set 8 | varhaug
# Processing Record 20 of Set 8 | parabel
# Processing Record 21 of Set 8 | tendukheda
# Processing Record 22 of Set 8 | swakopmund
# Processing Record 23 of Set 8 | uelzen
# Processing Record 24 of Set 8 | sur
# Processing Record 25 of Set 8 | kabompo
# Processing Record 26 of Set 8 | smithers
# Processing Record 27 of Set 8 | valparaiso
# Processing Record 28 of Set 8 | penzance
# Processing Record 29 of Set 8 | sabang
# Processing Record 30 of Set 8 | sobral
# Processing Record 31 of Set 8 | kloulklubed
# Processing Record 32 of Set 8 | bonthe
# Processing Record 33 of Set 8 | marsh harbour
# Processing Record 34 of Set 8 | lasa
# Processing Record 35 of Set 8 | puteyets
# Processing Record 36 of Set 8 | areosa
# Processing Record 37 of Set 8 | margate
# Processing Record 38 of Set 8 | guerrero negro
# Processing Record 39 of Set 8 | goundam
# Processing Record 40 of Set 8 | baykit
# Processing Record 41 of Set 8 | burkhala
# City not found. Skipping...
# Processing Record 42 of Set 8 | naryan-mar
# Processing Record 43 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 8 | berlevag
# Processing Record 45 of Set 8 | kudahuvadhoo
# Processing Record 46 of Set 8 | beni suef
# Processing Record 47 of Set 8 | la palma
# Processing Record 48 of Set 8 | oktyabrskiy
# Processing Record 49 of Set 8 | saint-georges
# Processing Record 50 of Set 8 | le vauclin
# Processing Record 1 of Set 9 | kalmunai
# Processing Record 2 of Set 9 | conde
# Processing Record 3 of Set 9 | kendari
# Processing Record 4 of Set 9 | matay
# Processing Record 5 of Set 9 | vetlanda
# Processing Record 6 of Set 9 | paamiut
# Processing Record 7 of Set 9 | osakarovka
# Processing Record 8 of Set 9 | ketchikan
# Processing Record 9 of Set 9 | wajima
# Processing Record 10 of Set 9 | imeni poliny osipenko
# Processing Record 11 of Set 9 | kununurra
# Processing Record 12 of Set 9 | northam
# Processing Record 13 of Set 9 | kahului
# Processing Record 14 of Set 9 | fortuna
# Processing Record 15 of Set 9 | limbang
# Processing Record 16 of Set 9 | sidi ali
# Processing Record 17 of Set 9 | griffith
# Processing Record 18 of Set 9 | oktyabrskoye
# Processing Record 19 of Set 9 | nizhniy kuranakh
# Processing Record 20 of Set 9 | kabinda
# Processing Record 21 of Set 9 | kondinskoye
# Processing Record 22 of Set 9 | locri
# Processing Record 23 of Set 9 | hvide sande
# Processing Record 24 of Set 9 | makasar
# Processing Record 25 of Set 9 | kumukh
# Processing Record 26 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 9 | saint-augustin
# Processing Record 28 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 9 | campo sesenta
# Processing Record 30 of Set 9 | brae
# Processing Record 31 of Set 9 | yar-sale
# Processing Record 32 of Set 9 | ambilobe
# Processing Record 33 of Set 9 | tomatlan
# Processing Record 34 of Set 9 | esna
# Processing Record 35 of Set 9 | san jeronimo
# Processing Record 36 of Set 9 | umkomaas
# Processing Record 37 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 38 of Set 9 | chapleau
# Processing Record 39 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 9 | alice springs
# Processing Record 41 of Set 9 | irkutsk
# Processing Record 42 of Set 9 | caravelas
# Processing Record 43 of Set 9 | karlskrona
# Processing Record 44 of Set 9 | requena
# Processing Record 45 of Set 9 | mathbaria
# Processing Record 46 of Set 9 | yatou
# Processing Record 47 of Set 9 | lagoa santa
# Processing Record 48 of Set 9 | la rioja
# Processing Record 49 of Set 9 | fortuna foothills
# Processing Record 50 of Set 9 | manitouwadge
# Processing Record 1 of Set 10 | harper
# Processing Record 2 of Set 10 | arinos
# Processing Record 3 of Set 10 | maposeni
# Processing Record 4 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 5 of Set 10 | carutapera
# Processing Record 6 of Set 10 | lesosibirsk
# Processing Record 7 of Set 10 | nanortalik
# Processing Record 8 of Set 10 | torbay
# Processing Record 9 of Set 10 | shkotovo-26
# City not found. Skipping...
# Processing Record 10 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 11 of Set 10 | quatre cocos
# Processing Record 12 of Set 10 | maraa
# Processing Record 13 of Set 10 | auki
# Processing Record 14 of Set 10 | alot
# Processing Record 15 of Set 10 | bilma
# Processing Record 16 of Set 10 | bassano
# Processing Record 17 of Set 10 | guarapari
# Processing Record 18 of Set 10 | ergani
# Processing Record 19 of Set 10 | nemuro
# Processing Record 20 of Set 10 | naze
# Processing Record 21 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 22 of Set 10 | mehamn
# Processing Record 23 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 10 | xining
# Processing Record 25 of Set 10 | aripuana
# Processing Record 26 of Set 10 | huazolotitlan
# City not found. Skipping...
# Processing Record 27 of Set 10 | porto walter
# Processing Record 28 of Set 10 | taunggyi
# Processing Record 29 of Set 10 | quelimane
# Processing Record 30 of Set 10 | disna
# Processing Record 31 of Set 10 | gigmoto
# Processing Record 32 of Set 10 | mount isa
# Processing Record 33 of Set 10 | sandwick
# Processing Record 34 of Set 10 | balurghat
# Processing Record 35 of Set 10 | bubaque
# Processing Record 36 of Set 10 | kiunga
# Processing Record 37 of Set 10 | santa cruz
# Processing Record 38 of Set 10 | veraval
# Processing Record 39 of Set 10 | dzhebariki-khaya
# Processing Record 40 of Set 10 | vestmannaeyjar
# Processing Record 41 of Set 10 | hasaki
# Processing Record 42 of Set 10 | kroya
# Processing Record 43 of Set 10 | beisfjord
# Processing Record 44 of Set 10 | posadas
# Processing Record 45 of Set 10 | kendal
# Processing Record 46 of Set 10 | katsuura
# Processing Record 47 of Set 10 | okato
# Processing Record 48 of Set 10 | taulabe
# Processing Record 49 of Set 10 | huilong
# Processing Record 50 of Set 10 | wenling
# Processing Record 1 of Set 11 | nouadhibou
# Processing Record 2 of Set 11 | vikhorevka
# Processing Record 3 of Set 11 | adre
# Processing Record 4 of Set 11 | lobito
# Processing Record 5 of Set 11 | shirvan
# Processing Record 6 of Set 11 | siwani
# City not found. Skipping...
# Processing Record 7 of Set 11 | petilia policastro
# Processing Record 8 of Set 11 | half moon bay
# Processing Record 9 of Set 11 | khagaria
# Processing Record 10 of Set 11 | khorixas
# Processing Record 11 of Set 11 | caxias
# Processing Record 12 of Set 11 | kavaratti
# Processing Record 13 of Set 11 | puerto plata
# Processing Record 14 of Set 11 | andenes
# Processing Record 15 of Set 11 | muli
# Processing Record 16 of Set 11 | jiazi
# Processing Record 17 of Set 11 | svetlyy
# Processing Record 18 of Set 11 | concarneau
# Processing Record 19 of Set 11 | killybegs
# Processing Record 20 of Set 11 | guanica
# Processing Record 21 of Set 11 | komsomolskiy
# Processing Record 22 of Set 11 | nesbyen
# Processing Record 23 of Set 11 | poum
# Processing Record 24 of Set 11 | launceston
# Processing Record 25 of Set 11 | ixtapa
# Processing Record 26 of Set 11 | ekhabi
# Processing Record 27 of Set 11 | umm kaddadah
# Processing Record 28 of Set 11 | salinas
# Processing Record 29 of Set 11 | lavrentiya
# Processing Record 30 of Set 11 | barcelos
# Processing Record 31 of Set 11 | marsala
# Processing Record 32 of Set 11 | coquimbo
# Processing Record 33 of Set 11 | bethalto
# Processing Record 34 of Set 11 | jibuti
# Processing Record 35 of Set 11 | olinda
# Processing Record 36 of Set 11 | kupang
# Processing Record 37 of Set 11 | alta floresta
# Processing Record 38 of Set 11 | obo
# Processing Record 39 of Set 11 | vanderhoof
# Processing Record 40 of Set 11 | luena
# Processing Record 41 of Set 11 | hyvinkaa
# Processing Record 42 of Set 11 | novobirilyussy
# Processing Record 43 of Set 11 | peleduy
# Processing Record 44 of Set 11 | ulaangom
# Processing Record 45 of Set 11 | dunmore town
# Processing Record 46 of Set 11 | esperantina
# Processing Record 47 of Set 11 | lorengau
# Processing Record 48 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 11 | koumac
# Processing Record 50 of Set 11 | bambanglipuro
# Processing Record 1 of Set 12 | nelson bay
# Processing Record 2 of Set 12 | shelburne
# Processing Record 3 of Set 12 | tsiroanomandidy
# Processing Record 4 of Set 12 | ust-kuyga
# Processing Record 5 of Set 12 | siavonga
# Processing Record 6 of Set 12 | marion
# Processing Record 7 of Set 12 | wilmington
# Processing Record 8 of Set 12 | altay
# Processing Record 9 of Set 12 | karangasem
# Processing Record 10 of Set 12 | venosa
# Processing Record 11 of Set 12 | kangaatsiaq
# Processing Record 12 of Set 12 | oranjestad
# Processing Record 13 of Set 12 | tlazazalca
# Processing Record 14 of Set 12 | tigil
# Processing Record 15 of Set 12 | sakaiminato
# Processing Record 16 of Set 12 | ewa beach
# Processing Record 17 of Set 12 | jabinyanah
# Processing Record 18 of Set 12 | goderich
# Processing Record 19 of Set 12 | itarema
# Processing Record 20 of Set 12 | ati
# Processing Record 21 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 12 | bitung
# Processing Record 23 of Set 12 | irbeyskoye
# Processing Record 24 of Set 12 | salym
# Processing Record 25 of Set 12 | wewak
# Processing Record 26 of Set 12 | serdobsk
# Processing Record 27 of Set 12 | tocopilla
# Processing Record 28 of Set 12 | ofunato
# Processing Record 29 of Set 12 | baruun-urt
# Processing Record 30 of Set 12 | hanzhong
# Processing Record 31 of Set 12 | gold coast
# Processing Record 32 of Set 12 | baglung
# Processing Record 33 of Set 12 | port-gentil
# Processing Record 34 of Set 12 | sao jose da coroa grande
# Processing Record 35 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 12 | deputatskiy
# Processing Record 37 of Set 12 | eyl
# Processing Record 38 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 12 | balykshi
# Processing Record 40 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 12 | rabo de peixe
# Processing Record 42 of Set 12 | tres picos
# Processing Record 43 of Set 12 | astoria
# Processing Record 44 of Set 12 | sitka
# Processing Record 45 of Set 12 | jhikargachha
# City not found. Skipping...
# Processing Record 46 of Set 12 | haldibari
# Processing Record 47 of Set 12 | olafsvik
# Processing Record 48 of Set 12 | beringovskiy
# Processing Record 49 of Set 12 | nioro
# Processing Record 50 of Set 12 | ocosingo
# Processing Record 1 of Set 13 | marrakesh
# Processing Record 2 of Set 13 | makakilo city
# Processing Record 3 of Set 13 | chernoyerkovskaya
# Processing Record 4 of Set 13 | mokhsogollokh
# Processing Record 5 of Set 13 | salalah
# Processing Record 6 of Set 13 | sri aman
# Processing Record 7 of Set 13 | broken hill
# Processing Record 8 of Set 13 | kamina
# Processing Record 9 of Set 13 | isangel
# Processing Record 10 of Set 13 | key west
# Processing Record 11 of Set 13 | joensuu
# Processing Record 12 of Set 13 | vastervik
# City not found. Skipping...
# Processing Record 13 of Set 13 | odweyne
# Processing Record 14 of Set 13 | pauini
# Processing Record 15 of Set 13 | sanandaj
# Processing Record 16 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 13 | moron
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Grindavik  63.8424  -22.4338     32.47        80          90
# 1       Victoria  22.2855  114.1577     62.58        41          38
# 2      Catamarca -28.4696  -65.7852     90.77        33           1
# 3  Leningradskiy  69.3833  178.4167    -21.73        96          49
# 4       Ust-Nera  64.5667  143.2000    -31.95        99          88
# 5    Yellowknife  62.4560 -114.3525    -19.68        76          20
# 6        Ushuaia -54.8000  -68.3000     62.26        34          40
# 7          Bluff -46.6000  168.3333     55.80        76          91
# 8    Tuktoyaktuk  69.4541 -133.0374    -29.20        68          20
# 9          Vaini -21.2000 -175.2000     80.76        83          40
#
#    Wind Speed Country                 Date
# 0       21.85      IS  2021-11-30 20:31:01
# 1        1.01      HK  2021-11-30 20:27:41
# 2       10.00      AR  2021-11-30 20:31:01
# 3       10.09      RU  2021-11-30 20:31:02
# 4        3.98      RU  2021-11-30 20:31:02
# 5        6.91      CA  2021-11-30 20:26:08
# 6       19.57      AR  2021-11-30 20:26:08
# 7       15.61      NZ  2021-11-30 20:26:13
# 8        6.91      CA  2021-11-30 20:31:03
# 9       11.50      TO  2021-11-30 20:26:12

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0      Grindavik      IS  2021-11-30 20:31:01  63.8424  -22.4338     32.47
# 1       Victoria      HK  2021-11-30 20:27:41  22.2855  114.1577     62.58
# 2      Catamarca      AR  2021-11-30 20:31:01 -28.4696  -65.7852     90.77
# 3  Leningradskiy      RU  2021-11-30 20:31:02  69.3833  178.4167    -21.73
# 4       Ust-Nera      RU  2021-11-30 20:31:02  64.5667  143.2000    -31.95
# 5    Yellowknife      CA  2021-11-30 20:26:08  62.4560 -114.3525    -19.68
# 6        Ushuaia      AR  2021-11-30 20:26:08 -54.8000  -68.3000     62.26
# 7          Bluff      NZ  2021-11-30 20:26:13 -46.6000  168.3333     55.80
# 8    Tuktoyaktuk      CA  2021-11-30 20:31:03  69.4541 -133.0374    -29.20
# 9          Vaini      TO  2021-11-30 20:26:12 -21.2000 -175.2000     80.76
#
#    Humidity  Cloudiness  Wind Speed
# 0        80          90       21.85
# 1        41          38        1.01
# 2        33           1       10.00
# 3        96          49       10.09
# 4        99          88        3.98
# 5        76          20        6.91
# 6        34          40       19.57
# 7        76          91       15.61
# 8        68          20        6.91
# 9        83          40       11.50

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

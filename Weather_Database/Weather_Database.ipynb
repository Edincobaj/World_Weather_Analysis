# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 593

# %%
# Import the requests library.
import requests

# Import the API Key.
from config2 import weather_api_key

#starting url for weather map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_weather = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | neepawa
# Processing Record 2 of Set 1 | portland
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | yulara
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | saldanha
# Processing Record 8 of Set 1 | kruisfontein
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | south daytona
# Processing Record 11 of Set 1 | port blair
# Processing Record 12 of Set 1 | isangel
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | dhidhdhoo
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | biloela
# Processing Record 17 of Set 1 | chlorakas
# Processing Record 18 of Set 1 | svobodnyy
# Processing Record 19 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 1 | sulangan
# Processing Record 21 of Set 1 | torbay
# Processing Record 22 of Set 1 | susanville
# Processing Record 23 of Set 1 | naze
# Processing Record 24 of Set 1 | platteville
# Processing Record 25 of Set 1 | mubende
# Processing Record 26 of Set 1 | mount gambier
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | geraldton
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | tiksi
# Processing Record 31 of Set 1 | kabompo
# Processing Record 32 of Set 1 | conceicao da barra
# Processing Record 33 of Set 1 | perth
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 1 | pran buri
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | seguela
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | jieshi
# Processing Record 41 of Set 1 | richards bay
# Processing Record 42 of Set 1 | krasnoselkup
# Processing Record 43 of Set 1 | banda aceh
# Processing Record 44 of Set 1 | taikang
# Processing Record 45 of Set 1 | norman wells
# Processing Record 46 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | akhtanizovskaya
# Processing Record 2 of Set 2 | evensk
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | vermilion
# Processing Record 5 of Set 2 | hami
# Processing Record 6 of Set 2 | matay
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | aasiaat
# Processing Record 9 of Set 2 | upernavik
# Processing Record 10 of Set 2 | mahibadhoo
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | alice springs
# Processing Record 14 of Set 2 | labuan
# Processing Record 15 of Set 2 | itarema
# Processing Record 16 of Set 2 | cabedelo
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | seoul
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | kiama
# Processing Record 21 of Set 2 | chirongui
# Processing Record 22 of Set 2 | kaeo
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | laguna
# Processing Record 25 of Set 2 | ushuaia
# Processing Record 26 of Set 2 | les cayes
# Processing Record 27 of Set 2 | road town
# Processing Record 28 of Set 2 | umred
# Processing Record 29 of Set 2 | xingcheng
# Processing Record 30 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 2 | shingu
# Processing Record 32 of Set 2 | luwingu
# Processing Record 33 of Set 2 | maragogi
# Processing Record 34 of Set 2 | kedrovyy
# Processing Record 35 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 36 of Set 2 | pevek
# Processing Record 37 of Set 2 | guilin
# Processing Record 38 of Set 2 | chimbote
# Processing Record 39 of Set 2 | kontagora
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | mar del plata
# Processing Record 42 of Set 2 | mount isa
# Processing Record 43 of Set 2 | chase
# Processing Record 44 of Set 2 | fortuna
# Processing Record 45 of Set 2 | yarada
# Processing Record 46 of Set 2 | sorland
# Processing Record 47 of Set 2 | kazachinskoye
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | vila franca do campo
# Processing Record 50 of Set 2 | severo-kurilsk
# Processing Record 1 of Set 3 | tasiilaq
# Processing Record 2 of Set 3 | yerkoy
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | port keats
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | calafell
# Processing Record 7 of Set 3 | klaksvik
# Processing Record 8 of Set 3 | mananjary
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | kavieng
# Processing Record 11 of Set 3 | qui nhon
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | sao filipe
# Processing Record 14 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 15 of Set 3 | kutahya
# Processing Record 16 of Set 3 | ilhabela
# Processing Record 17 of Set 3 | maniitsoq
# Processing Record 18 of Set 3 | ryotsu
# Processing Record 19 of Set 3 | aklavik
# Processing Record 20 of Set 3 | maarianhamina
# Processing Record 21 of Set 3 | tuatapere
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | dunedin
# Processing Record 24 of Set 3 | chauk
# Processing Record 25 of Set 3 | hithadhoo
# Processing Record 26 of Set 3 | nha trang
# Processing Record 27 of Set 3 | sotouboua
# Processing Record 28 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 3 | bluff
# Processing Record 30 of Set 3 | broken hill
# Processing Record 31 of Set 3 | asau
# Processing Record 32 of Set 3 | castro
# Processing Record 33 of Set 3 | olinda
# Processing Record 34 of Set 3 | jamestown
# Processing Record 35 of Set 3 | parati
# Processing Record 36 of Set 3 | codrington
# Processing Record 37 of Set 3 | zeya
# Processing Record 38 of Set 3 | hambantota
# Processing Record 39 of Set 3 | hasaki
# Processing Record 40 of Set 3 | sokolo
# Processing Record 41 of Set 3 | sharan
# Processing Record 42 of Set 3 | mitu
# Processing Record 43 of Set 3 | erenhot
# Processing Record 44 of Set 3 | mugur-aksy
# Processing Record 45 of Set 3 | carnarvon
# Processing Record 46 of Set 3 | kristiinankaupunki
# Processing Record 47 of Set 3 | mehamn
# Processing Record 48 of Set 3 | borujerd
# Processing Record 49 of Set 3 | lebu
# Processing Record 50 of Set 3 | coquimbo
# Processing Record 1 of Set 4 | oksfjord
# Processing Record 2 of Set 4 | ocos
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | dong hoi
# Processing Record 5 of Set 4 | nabinagar
# Processing Record 6 of Set 4 | avarua
# Processing Record 7 of Set 4 | bondo
# Processing Record 8 of Set 4 | sakakah
# Processing Record 9 of Set 4 | cap-aux-meules
# Processing Record 10 of Set 4 | yanam
# Processing Record 11 of Set 4 | san quintin
# Processing Record 12 of Set 4 | sillamae
# Processing Record 13 of Set 4 | aswan
# Processing Record 14 of Set 4 | georgetown
# Processing Record 15 of Set 4 | kavaratti
# Processing Record 16 of Set 4 | maues
# Processing Record 17 of Set 4 | tevaitoa
# Processing Record 18 of Set 4 | okotoks
# Processing Record 19 of Set 4 | saskylakh
# Processing Record 20 of Set 4 | raudeberg
# Processing Record 21 of Set 4 | chokurdakh
# Processing Record 22 of Set 4 | bengkulu
# Processing Record 23 of Set 4 | luebo
# Processing Record 24 of Set 4 | maryborough
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | palomares
# Processing Record 27 of Set 4 | lokosovo
# Processing Record 28 of Set 4 | port alfred
# Processing Record 29 of Set 4 | khandyga
# Processing Record 30 of Set 4 | butaritari
# Processing Record 31 of Set 4 | cabo san lucas
# Processing Record 32 of Set 4 | namibe
# Processing Record 33 of Set 4 | teya
# Processing Record 34 of Set 4 | zhicheng
# Processing Record 35 of Set 4 | solnechnyy
# Processing Record 36 of Set 4 | sidi ali
# Processing Record 37 of Set 4 | saint-francois
# Processing Record 38 of Set 4 | sumbawanga
# Processing Record 39 of Set 4 | chuy
# Processing Record 40 of Set 4 | camacha
# Processing Record 41 of Set 4 | dolores
# Processing Record 42 of Set 4 | alofi
# Processing Record 43 of Set 4 | kipini
# Processing Record 44 of Set 4 | omboue
# Processing Record 45 of Set 4 | luderitz
# Processing Record 46 of Set 4 | soignies
# Processing Record 47 of Set 4 | merauke
# Processing Record 48 of Set 4 | hobart
# Processing Record 49 of Set 4 | lasa
# Processing Record 50 of Set 4 | biak
# Processing Record 1 of Set 5 | sitka
# Processing Record 2 of Set 5 | pangnirtung
# Processing Record 3 of Set 5 | new norfolk
# Processing Record 4 of Set 5 | kodiak
# Processing Record 5 of Set 5 | atambua
# Processing Record 6 of Set 5 | souillac
# Processing Record 7 of Set 5 | portobelo
# Processing Record 8 of Set 5 | narrabri
# Processing Record 9 of Set 5 | ponta delgada
# Processing Record 10 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 5 | tazovskiy
# Processing Record 13 of Set 5 | qaqortoq
# Processing Record 14 of Set 5 | shimanovsk
# Processing Record 15 of Set 5 | puerto madryn
# Processing Record 16 of Set 5 | hanna
# Processing Record 17 of Set 5 | bezhta
# Processing Record 18 of Set 5 | srednekolymsk
# Processing Record 19 of Set 5 | chapais
# Processing Record 20 of Set 5 | khatanga
# Processing Record 21 of Set 5 | basoko
# Processing Record 22 of Set 5 | lata
# Processing Record 23 of Set 5 | hammerfest
# Processing Record 24 of Set 5 | ilulissat
# Processing Record 25 of Set 5 | victoria
# Processing Record 26 of Set 5 | sangar
# Processing Record 27 of Set 5 | burnie
# Processing Record 28 of Set 5 | otane
# Processing Record 29 of Set 5 | pafos
# Processing Record 30 of Set 5 | svetlyy
# Processing Record 31 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 5 | faya
# Processing Record 33 of Set 5 | rio gallegos
# Processing Record 34 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 5 | yeppoon
# Processing Record 36 of Set 5 | san juan
# Processing Record 37 of Set 5 | kaitangata
# Processing Record 38 of Set 5 | karratha
# Processing Record 39 of Set 5 | garden city
# Processing Record 40 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 5 | kemin
# Processing Record 42 of Set 5 | valdivia
# Processing Record 43 of Set 5 | shirgaon
# Processing Record 44 of Set 5 | raduzhnyy
# Processing Record 45 of Set 5 | loa janan
# Processing Record 46 of Set 5 | lianzhou
# Processing Record 47 of Set 5 | linkoping
# Processing Record 48 of Set 5 | miracema do tocantins
# Processing Record 49 of Set 5 | bulgan
# Processing Record 50 of Set 5 | angoche
# Processing Record 1 of Set 6 | rio grande
# Processing Record 2 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 6 | ponta do sol
# Processing Record 4 of Set 6 | cidreira
# Processing Record 5 of Set 6 | coihaique
# Processing Record 6 of Set 6 | kota tinggi
# Processing Record 7 of Set 6 | baracoa
# Processing Record 8 of Set 6 | mayo
# Processing Record 9 of Set 6 | wajir
# Processing Record 10 of Set 6 | ancud
# Processing Record 11 of Set 6 | marawi
# Processing Record 12 of Set 6 | baker city
# Processing Record 13 of Set 6 | jalu
# Processing Record 14 of Set 6 | lompoc
# Processing Record 15 of Set 6 | agadez
# Processing Record 16 of Set 6 | jaciara
# Processing Record 17 of Set 6 | batagay-alyta
# Processing Record 18 of Set 6 | flinders
# Processing Record 19 of Set 6 | muravlenko
# Processing Record 20 of Set 6 | huaicheng
# Processing Record 21 of Set 6 | matara
# Processing Record 22 of Set 6 | freeport
# Processing Record 23 of Set 6 | maun
# Processing Record 24 of Set 6 | egvekinot
# Processing Record 25 of Set 6 | poya
# Processing Record 26 of Set 6 | east london
# Processing Record 27 of Set 6 | tabuan
# Processing Record 28 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | boa vista
# Processing Record 30 of Set 6 | iqaluit
# Processing Record 31 of Set 6 | nanortalik
# Processing Record 32 of Set 6 | awjilah
# Processing Record 33 of Set 6 | amga
# Processing Record 34 of Set 6 | noshiro
# Processing Record 35 of Set 6 | la ronge
# Processing Record 36 of Set 6 | anapolis
# Processing Record 37 of Set 6 | henties bay
# Processing Record 38 of Set 6 | vitoria da conquista
# Processing Record 39 of Set 6 | fairbanks
# Processing Record 40 of Set 6 | patacamaya
# Processing Record 41 of Set 6 | yinchuan
# Processing Record 42 of Set 6 | sibolga
# Processing Record 43 of Set 6 | barrow
# Processing Record 44 of Set 6 | vangaindrano
# Processing Record 45 of Set 6 | acarau
# Processing Record 46 of Set 6 | bathsheba
# Processing Record 47 of Set 6 | zimapan
# Processing Record 48 of Set 6 | la seyne-sur-mer
# Processing Record 49 of Set 6 | bethel
# Processing Record 50 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 7 | santa cruz
# Processing Record 2 of Set 7 | palora
# Processing Record 3 of Set 7 | vadso
# Processing Record 4 of Set 7 | nuuk
# Processing Record 5 of Set 7 | jumla
# Processing Record 6 of Set 7 | yerbogachen
# Processing Record 7 of Set 7 | lerwick
# Processing Record 8 of Set 7 | carutapera
# Processing Record 9 of Set 7 | katsuura
# Processing Record 10 of Set 7 | oxelosund
# Processing Record 11 of Set 7 | middelburg
# Processing Record 12 of Set 7 | te anau
# Processing Record 13 of Set 7 | derzhavinsk
# Processing Record 14 of Set 7 | sola
# Processing Record 15 of Set 7 | sotnikovskoye
# Processing Record 16 of Set 7 | quechultenango
# Processing Record 17 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 7 | tautira
# Processing Record 19 of Set 7 | andros town
# Processing Record 20 of Set 7 | altay
# Processing Record 21 of Set 7 | sao miguel do araguaia
# Processing Record 22 of Set 7 | fuerte olimpo
# Processing Record 23 of Set 7 | rawson
# Processing Record 24 of Set 7 | sidi qasim
# City not found. Skipping...
# Processing Record 25 of Set 7 | ambovombe
# Processing Record 26 of Set 7 | banyuwangi
# Processing Record 27 of Set 7 | te karaka
# Processing Record 28 of Set 7 | san martin
# Processing Record 29 of Set 7 | marsaxlokk
# Processing Record 30 of Set 7 | saurimo
# Processing Record 31 of Set 7 | belyye berega
# Processing Record 32 of Set 7 | benalla
# Processing Record 33 of Set 7 | college
# Processing Record 34 of Set 7 | lar
# Processing Record 35 of Set 7 | kununurra
# Processing Record 36 of Set 7 | kafue
# Processing Record 37 of Set 7 | leningradskiy
# Processing Record 38 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 7 | sioux lookout
# Processing Record 40 of Set 7 | menongue
# Processing Record 41 of Set 7 | port lincoln
# Processing Record 42 of Set 7 | shenzhen
# Processing Record 43 of Set 7 | ketchikan
# Processing Record 44 of Set 7 | la paz
# Processing Record 45 of Set 7 | whitehorse
# Processing Record 46 of Set 7 | bokaro
# Processing Record 47 of Set 7 | ondangwa
# Processing Record 48 of Set 7 | husavik
# Processing Record 49 of Set 7 | bam
# Processing Record 50 of Set 7 | cooma
# Processing Record 1 of Set 8 | ostrovnoy
# Processing Record 2 of Set 8 | santa rosa
# Processing Record 3 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 4 of Set 8 | san rafael del sur
# Processing Record 5 of Set 8 | mitsamiouli
# Processing Record 6 of Set 8 | constitucion
# Processing Record 7 of Set 8 | alekseyevka
# Processing Record 8 of Set 8 | makarov
# Processing Record 9 of Set 8 | bubaque
# Processing Record 10 of Set 8 | brigantine
# Processing Record 11 of Set 8 | bagotville
# Processing Record 12 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 8 | cruzilia
# Processing Record 14 of Set 8 | ribeira grande
# Processing Record 15 of Set 8 | diego de almagro
# Processing Record 16 of Set 8 | katherine
# Processing Record 17 of Set 8 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 18 of Set 8 | saint-pierre
# Processing Record 19 of Set 8 | batagay
# Processing Record 20 of Set 8 | narasannapeta
# Processing Record 21 of Set 8 | panixtlahuaca
# City not found. Skipping...
# Processing Record 22 of Set 8 | westport
# Processing Record 23 of Set 8 | vardo
# Processing Record 24 of Set 8 | port-gentil
# Processing Record 25 of Set 8 | windhoek
# Processing Record 26 of Set 8 | san jeronimo
# Processing Record 27 of Set 8 | marzuq
# Processing Record 28 of Set 8 | nome
# Processing Record 29 of Set 8 | vieques
# Processing Record 30 of Set 8 | sao felix do xingu
# Processing Record 31 of Set 8 | lavrentiya
# Processing Record 32 of Set 8 | truro
# Processing Record 33 of Set 8 | san patricio
# Processing Record 34 of Set 8 | brae
# Processing Record 35 of Set 8 | meadville
# Processing Record 36 of Set 8 | severnyy-kospashskiy
# Processing Record 37 of Set 8 | sabang
# Processing Record 38 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 39 of Set 8 | tongchuan
# Processing Record 40 of Set 8 | ishim
# Processing Record 41 of Set 8 | port macquarie
# Processing Record 42 of Set 8 | minas novas
# Processing Record 43 of Set 8 | kieta
# Processing Record 44 of Set 8 | vestmanna
# Processing Record 45 of Set 8 | maykor
# Processing Record 46 of Set 8 | noumea
# Processing Record 47 of Set 8 | keskin
# Processing Record 48 of Set 8 | sturgeon bay
# Processing Record 49 of Set 8 | gimli
# Processing Record 50 of Set 8 | copiapo
# Processing Record 1 of Set 9 | saint george
# Processing Record 2 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 9 | bad hofgastein
# Processing Record 4 of Set 9 | machiques
# Processing Record 5 of Set 9 | aksu
# Processing Record 6 of Set 9 | komsomolskiy
# Processing Record 7 of Set 9 | labuhan
# Processing Record 8 of Set 9 | nilanga
# Processing Record 9 of Set 9 | dingle
# Processing Record 10 of Set 9 | saint-paul
# Processing Record 11 of Set 9 | aquin
# Processing Record 12 of Set 9 | ullapool
# Processing Record 13 of Set 9 | mola di bari
# Processing Record 14 of Set 9 | caravelas
# Processing Record 15 of Set 9 | laje
# Processing Record 16 of Set 9 | korla
# Processing Record 17 of Set 9 | suslovo
# Processing Record 18 of Set 9 | tecoanapa
# Processing Record 19 of Set 9 | asasa
# Processing Record 20 of Set 9 | opunake
# Processing Record 21 of Set 9 | hukuntsi
# Processing Record 22 of Set 9 | tessalit
# Processing Record 23 of Set 9 | roma
# Processing Record 24 of Set 9 | sasebo
# Processing Record 25 of Set 9 | the valley
# Processing Record 26 of Set 9 | angra
# City not found. Skipping...
# Processing Record 27 of Set 9 | pangai
# Processing Record 28 of Set 9 | tahe
# Processing Record 29 of Set 9 | luwuk
# Processing Record 30 of Set 9 | gejiu
# Processing Record 31 of Set 9 | birao
# Processing Record 32 of Set 9 | longhua
# Processing Record 33 of Set 9 | porangatu
# Processing Record 34 of Set 9 | xiongyue
# Processing Record 35 of Set 9 | urucui
# Processing Record 36 of Set 9 | kuching
# Processing Record 37 of Set 9 | cururupu
# Processing Record 38 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 9 | manta
# Processing Record 40 of Set 9 | kamenka
# Processing Record 41 of Set 9 | bima
# Processing Record 42 of Set 9 | eyl
# Processing Record 43 of Set 9 | bangalore
# Processing Record 44 of Set 9 | umarga
# Processing Record 45 of Set 9 | perbaungan
# Processing Record 46 of Set 9 | cozumel
# Processing Record 47 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 9 | petrovsk
# Processing Record 49 of Set 9 | bonthe
# Processing Record 50 of Set 9 | berdyuzhye
# City not found. Skipping...
# Processing Record 1 of Set 10 | praia
# Processing Record 2 of Set 10 | narsaq
# Processing Record 3 of Set 10 | jiexiu
# Processing Record 4 of Set 10 | lyuban
# Processing Record 5 of Set 10 | cadillac
# Processing Record 6 of Set 10 | el tarra
# Processing Record 7 of Set 10 | ahipara
# Processing Record 8 of Set 10 | tazmalt
# Processing Record 9 of Set 10 | niksar
# Processing Record 10 of Set 10 | tual
# Processing Record 11 of Set 10 | cayenne
# Processing Record 12 of Set 10 | vila velha
# Processing Record 13 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 10 | cockburn town
# Processing Record 15 of Set 10 | kenai
# Processing Record 16 of Set 10 | limanowa
# Processing Record 17 of Set 10 | strezhevoy
# Processing Record 18 of Set 10 | ekhabi
# Processing Record 19 of Set 10 | turan
# Processing Record 20 of Set 10 | port hedland
# Processing Record 21 of Set 10 | sinnamary
# Processing Record 22 of Set 10 | mutoko
# Processing Record 23 of Set 10 | north bend
# Processing Record 24 of Set 10 | cherskiy
# Processing Record 25 of Set 10 | lagoa
# Processing Record 26 of Set 10 | akyab
# Processing Record 27 of Set 10 | finnsnes
# Processing Record 28 of Set 10 | san cristobal
# Processing Record 29 of Set 10 | ambilobe
# Processing Record 30 of Set 10 | saint-georges
# Processing Record 31 of Set 10 | bure
# Processing Record 32 of Set 10 | kawalu
# Processing Record 33 of Set 10 | meiganga
# Processing Record 34 of Set 10 | kysyl-syr
# Processing Record 35 of Set 10 | maxixe
# Processing Record 36 of Set 10 | pisco
# Processing Record 37 of Set 10 | aykhal
# Processing Record 38 of Set 10 | kajaani
# Processing Record 39 of Set 10 | charters towers
# Processing Record 40 of Set 10 | tubuala
# Processing Record 41 of Set 10 | landang
# City not found. Skipping...
# Processing Record 42 of Set 10 | manggar
# Processing Record 43 of Set 10 | visavadar
# Processing Record 44 of Set 10 | broome
# Processing Record 45 of Set 10 | zyryanka
# Processing Record 46 of Set 10 | adrar
# Processing Record 47 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 48 of Set 10 | sao domingos
# Processing Record 49 of Set 10 | jaque
# Processing Record 50 of Set 10 | katha
# City not found. Skipping...
# Processing Record 1 of Set 11 | berdigestyakh
# Processing Record 2 of Set 11 | esperance
# Processing Record 3 of Set 11 | cerknica
# Processing Record 4 of Set 11 | tagab
# Processing Record 5 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 11 | oistins
# Processing Record 7 of Set 11 | salisbury
# Processing Record 8 of Set 11 | hay river
# Processing Record 9 of Set 11 | liaocheng
# Processing Record 10 of Set 11 | play cu
# City not found. Skipping...
# Processing Record 11 of Set 11 | oranjemund
# Processing Record 12 of Set 11 | mali
# Processing Record 13 of Set 11 | jiujiang
# Processing Record 14 of Set 11 | markova
# Processing Record 15 of Set 11 | sao jose da coroa grande
# Processing Record 16 of Set 11 | kabare
# Processing Record 17 of Set 11 | panama city
# Processing Record 18 of Set 11 | luangwa
# Processing Record 19 of Set 11 | poum
# Processing Record 20 of Set 11 | sobolevo
# Processing Record 21 of Set 11 | ishigaki
# Processing Record 22 of Set 11 | bay roberts
# Processing Record 23 of Set 11 | daru
# Processing Record 24 of Set 11 | zeerust
# Processing Record 25 of Set 11 | andenes
# Processing Record 26 of Set 11 | kinsale
# Processing Record 27 of Set 11 | lampazos de naranjo
# Processing Record 28 of Set 11 | pasinler
# Processing Record 29 of Set 11 | vostok
# Processing Record 30 of Set 11 | taicheng
# Processing Record 31 of Set 11 | puerto escondido
# Processing Record 32 of Set 11 | aketi
# Processing Record 33 of Set 11 | shimoda
# Processing Record 34 of Set 11 | pacific grove
# Processing Record 35 of Set 11 | panzhihua
# Processing Record 36 of Set 11 | shangrao
# Processing Record 37 of Set 11 | lubango
# Processing Record 38 of Set 11 | olafsvik
# Processing Record 39 of Set 11 | clyde river
# Processing Record 40 of Set 11 | vestmannaeyjar
# Processing Record 41 of Set 11 | itupiranga
# Processing Record 42 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 11 | vanimo
# Processing Record 44 of Set 11 | lorengau
# Processing Record 45 of Set 11 | nuevo progreso
# Processing Record 46 of Set 11 | mackenzie
# Processing Record 47 of Set 11 | gualeguay
# Processing Record 48 of Set 11 | foz
# Processing Record 49 of Set 11 | cabadiangan
# Processing Record 50 of Set 11 | dongying
# Processing Record 1 of Set 12 | wesselsbron
# Processing Record 2 of Set 12 | opuwo
# Processing Record 3 of Set 12 | talnakh
# Processing Record 4 of Set 12 | payakumbuh
# Processing Record 5 of Set 12 | grande-riviere
# City not found. Skipping...
# Processing Record 6 of Set 12 | pouembout
# Processing Record 7 of Set 12 | bara
# Processing Record 8 of Set 12 | anchorage
# Processing Record 9 of Set 12 | taoudenni
# Processing Record 10 of Set 12 | sibenik
# Processing Record 11 of Set 12 | iquique
# Processing Record 12 of Set 12 | grindavik
# Processing Record 13 of Set 12 | pontianak
# Processing Record 14 of Set 12 | ranong
# Processing Record 15 of Set 12 | tabuk
# Processing Record 16 of Set 12 | alyangula
# Processing Record 17 of Set 12 | atar
# Processing Record 18 of Set 12 | port hardy
# Processing Record 19 of Set 12 | mantua
# Processing Record 20 of Set 12 | beringovskiy
# Processing Record 21 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 12 | kushima
# Processing Record 23 of Set 12 | buraydah
# Processing Record 24 of Set 12 | inhambane
# Processing Record 25 of Set 12 | goderich
# Processing Record 26 of Set 12 | ban chang
# Processing Record 27 of Set 12 | los llanos de aridane
# Processing Record 28 of Set 12 | adre
# Processing Record 29 of Set 12 | villarrica
# Processing Record 30 of Set 12 | kloulklubed
# Processing Record 31 of Set 12 | ybycui
# Processing Record 32 of Set 12 | qostanay
# Processing Record 33 of Set 12 | kodinsk
# Processing Record 34 of Set 12 | tilichiki
# Processing Record 35 of Set 12 | ostroh
# Processing Record 36 of Set 12 | quatre cocos
# Processing Record 37 of Set 12 | stornoway
# Processing Record 38 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 12 | zaykovo
# Processing Record 40 of Set 12 | paratinga
# Processing Record 41 of Set 12 | jaljulye
# City not found. Skipping...
# Processing Record 42 of Set 12 | north platte
# Processing Record 43 of Set 12 | cantaura
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Neepawa  50.2289  -99.4664     36.00        83         100
# 1       Portland  45.5234 -122.6762     55.38        94          75
# 2     Bredasdorp -34.5322   20.0403     63.28        68          94
# 3         Yulara -25.2406  130.9889     84.04        17           0
# 4   Punta Arenas -53.1500  -70.9167     55.51        41          40
# 5    Provideniya  64.3833 -173.3000     -3.48        66           0
# 6       Saldanha -33.0117   17.9442     62.42        77          49
# 7   Kruisfontein -34.0033   24.7314     71.89        84           6
# 8   Puerto Ayora  -0.7393  -90.3518     76.96        76          78
# 9  South Daytona  29.1658  -81.0045     77.09        55          20
#
#    Wind Speed Country Current Description
# 0       24.94      CA     overcast clouds
# 1        3.00      US                mist
# 2       12.39      ZA     overcast clouds
# 3       10.36      AU           clear sky
# 4       16.11      CL    scattered clouds
# 5        5.03      RU           clear sky
# 6       24.67      ZA    scattered clouds
# 7        6.69      ZA          light rain
# 8        8.86      EC       broken clouds
# 9        6.91      US          few clouds

# %%
# Create the output to a csv file
output_data_file = 'Weather_Database/WeatherPy_Database.csv'

# Export the city data into a CSV
city_data_df.to_csv('WeatherPy_Database.csv')
